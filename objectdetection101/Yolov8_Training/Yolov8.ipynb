# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="F1ty1cwrvf2EkiSoyD3N")
project = rf.workspace("roboflow-universe-projects").project("construction-site-safety")
dataset = project.version(30).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 8.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.4 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=b0eb7016b76b85a3b93be8a693f133d3e9bba1dd8dcd068274a97f2adb094e68
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
# ...

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://cdn.stocksnap.io/img-thumbs/960w/philadelphia-travel_LPDQBLM2A0.jpg'
# Out:
# ...
# 100% 83.7M/83.7M [00:04<00:00, 19.3MB/s]
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients
#
# ...
# 100% 790k/790k [00:00<00:00, 123MB/s]
# image 1/1 /content/philadelphia-travel_LPDQBLM2A0.jpg: 448x640 5 persons, 2 buss, 2 handbags, 69.3ms
# Speed: 11.4ms preprocess, 69.3ms inference, 19.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# ##**Custom Training**
# - data.yaml file format:
#
# names:
# - Excavator
# - Gloves
# - Hardhat
# - Ladder
# - Mask
# - NO-Hardhat
# - NO-Mask
# - NO-Safety Vest
# - Person
# - SUV
# - Safety Cone
# - Safety Vest
# - bus
# - dump truck
# - fire hydrant
# - machinery
# - mini-van
# - sedan
# - semi
# - trailer
# - truck and trailer
# - truck
# - van
# - vehicle
# - wheel loader
# nc: 25
#
# path: /content/Construction-Site-Safety-30
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/Construction-Site-Safety-30/data.yaml epochs =50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
